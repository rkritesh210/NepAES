# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import numpy as np
from sklearn import datasets, linear_model, metrics
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVR
from sklearn import svm
import xgboost
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

# %%
df = pd.read_csv('/content/drive/MyDrive/EG/translated_dataset/google_translator/nep_p8_fe.csv')

# %%
df.head(5)
# Out:
#    index  essay_id  essay_set  \
# 0      0         1          1
# 1      1         2          1
# 2      2         3          1
# 3      3         4          1
# 4      4         5          1
#
#                                                essay  score  \
# 0  Dear local newspaper, I think effects computer...      8
# 1  Dear @CAPS1 @CAPS2, I believe that using compu...      9
# 2  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...      7
# 3  Dear Local Newspaper, @CAPS1 I have found that...     10
# 4  Dear @LOCATION1, I know having computers has a...      8
#
#                                          essay_hindi  \
# 0  प्रिय स्थानीय समाचार पत्र, मुझे लगता है कि लोग...
# 1                  प्रिय @ CAPS1 @ CAPS2, मेरा मानना
# 2  प्रिय, @ CAPS1 @ CAPS2 @ CAPS3 अधिक से अधिक लो...
# 3  प्रिय स्थानीय समाचार पत्र, @ CAPS1 मैंने पाया ...
# 4  प्रिय @LOCATION1, मुझे पता है कि कंप्यूटर का ल...
#
#                                         google_trans  \
# 0  प्रिय स्थानीय अखबार, मलाई लाग्छ कम्प्युटरहरूले...
# 1  प्रिय   , मलाई विश्वास छ कि कम्प्यूटरको प्रयोग...
# 2  प्रिय,    धेरै भन्दा धेरै मानिसहरूले कम्प्युटर...
# 3  प्रिय स्थानीय समाचार पत्र,  मैले फेला पारेको छ...
# 4  प्रिय  , मलाई थाहा छ कम्प्युटर हुनुले मानिसहरू...
#
#                                          mbart50_m2m  vocab_size  \
# 0  प्रिय स्थानीय समाचारपत्र, म सोच्दछु कम्प्युटरल...         132
# 1  प्रिय   , म विश्वास गर्दछु कम्प्युटरको प्रयोगल...         169
# 2  प्रिय,    धेरै मानिसहरूले कम्प्युटर प्रयोग गर्...         106
# 3  प्रिय स्थानीय समाचारपत्र,  मैले फेला परें कि ध...         196
# 4  प्रिय  , म जान्दछु कम्प्युटर भएकोले मानिसहरूमा...         173
#
#    unique_words_count  overlap_score  essay_length  average_sentence_length  \
# 0                 108       0.016957           287                16.882353
# 1                 124       0.001016           367                17.476190
# 2                  83       0.000517           230                15.333333
# 3                 158       0.001162           422                15.629630
# 4                 128       0.000890           367                11.838710
#
#    average_word_length  readability
# 0             5.794425    11.840070
# 1             5.561308    11.651199
# 2             5.773913    11.406174
# 3             5.699052    12.305972
# 4             5.760218    12.156866

# %%
def LR2():
    try:
        df = pd.read_csv('/content/drive/MyDrive/EG/translated_dataset/google_translator/nep_p8_fe.csv')
        df.overlap_score = (df.overlap_score - df.overlap_score.min()) / (df.overlap_score.max() - df.overlap_score.min())
        df.unique_words_count = (df.unique_words_count - df.unique_words_count.min()) / (df.unique_words_count.max() - df.unique_words_count.min())
        df.essay_length = (df.essay_length - df.essay_length.min()) / (df.essay_length.max() - df.essay_length.min())
        df.average_sentence_length = (df.average_sentence_length - df.average_sentence_length.min()) / (
                    df.average_sentence_length.max() - df.average_sentence_length.min())
        df.average_word_length = (df.average_word_length - df.average_word_length.min()) / (
                    df.average_word_length.max() - df.average_word_length.min())
        df.readability = (df.readability - df.readability.min()) / (df.readability.max() - df.readability.min())


        df = df.dropna(subset=['score']) # Drop rows with NaN values in the target variable 'score'

        x = df[['unique_words_count', 'overlap_score', 'essay_length', 'average_sentence_length', 'average_word_length', 'readability']]
        y = df['score']
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
        x_test, x_valid, y_test, y_valid = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

        lr = LinearRegression()
        lr.fit(x_train, y_train)
        y_pred = lr.predict(x_test)
        y_pred = np.around(y_pred, 0)

        qwk = metrics.cohen_kappa_score(y_test, y_pred, labels=None, weights='quadratic', sample_weight=None)
        print("Quadratic Weighted Kappa for Linear Regression:" + " " + str(qwk))
    except Exception as e:
        print("Error:", str(e))

# Call the function
LR2()
# Out:
# Quadratic Weighted Kappa for Linear Regression: 0.7813766441060934

# %%
def RF():
  # a=x
  try:
    name="/content/drive/MyDrive/EG/translated_dataset/google_translator/nep_p8_fe"
    name=name+'.csv'
    df = pd.read_csv(name, encoding = 'utf-8', engine = None)
    df.overlap_score= (df.overlap_score-df.overlap_score.min())/(df.overlap_score.max()-df.overlap_score.min())
    df.unique_words_count= (df.unique_words_count-df.unique_words_count.min())/(df.unique_words_count.max()-df.unique_words_count.min())
    df.essay_length= (df.essay_length-df.essay_length.min())/(df.essay_length.max()-df.essay_length.min())
    df.average_sentence_length= (df.average_sentence_length-df.average_sentence_length.min())/(df.average_sentence_length.max()-df.average_sentence_length.min())
    df.average_word_length= (df.average_word_length-df.average_word_length.min())/(df.average_word_length.max()-df.average_word_length.min())
    df.readability= (df.readability-df.readability.min())/(df.readability.max()-df.readability.min())
    df = df.dropna(subset=['score'])
    x=df[['unique_words_count','overlap_score','essay_length','average_sentence_length','average_word_length','readability']]
    y=df['score']
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=42)

    x_test, x_valid, y_test, y_valid = train_test_split(x_test, y_test, test_size = 0.5, random_state=42)

    clf = RandomForestClassifier(n_estimators = 30,max_depth=27,min_samples_split=4, random_state=42)
    clf.fit(x_train, y_train)
    y_pred = clf.predict(x_test)
    # print(y_pred)
    qwk=metrics.cohen_kappa_score(y_test, y_pred, labels=None, weights='quadratic', sample_weight=None)
    print("Quadratic Weighted Kappa for Random Forest:"+" "+str(qwk))
  except:
    print("Error in prompt ")

RF()
# Out:
# Quadratic Weighted Kappa for Random Forest: 0.7368328600286911

# %%
c=[]
def SV(C):
  # a=x
  # try:
  name="/content/drive/MyDrive/EG/translated_dataset/google_translator/nep_p8_fe"
  name=name+'.csv'
  df = pd.read_csv(name)
  df.overlap_score= (df.overlap_score-df.overlap_score.min())/(df.overlap_score.max()-df.overlap_score.min())
  df.unique_words_count= (df.unique_words_count-df.unique_words_count.min())/(df.unique_words_count.max()-df.unique_words_count.min())
  df.essay_length= (df.essay_length-df.essay_length.min())/(df.essay_length.max()-df.essay_length.min())
  df.average_sentence_length= (df.average_sentence_length-df.average_sentence_length.min())/(df.average_sentence_length.max()-df.average_sentence_length.min())
  df.average_word_length= (df.average_word_length-df.average_word_length.min())/(df.average_word_length.max()-df.average_word_length.min())
  df.readability= (df.readability-df.readability.min())/(df.readability.max()-df.readability.min())
  df = df.dropna(subset=['score'])
  x=df[['unique_words_count','overlap_score','essay_length','average_sentence_length','average_word_length','readability']]
  y=df['score']
  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=42)
  x_test, x_valid, y_test, y_valid = train_test_split(x_test, y_test, test_size = 0.5, random_state=42)
  y_train = np.asarray(y_train)
  y_train=y_train.reshape(-1,1)
  regressor = SVR(kernel = 'rbf',C=C)
  regressor.fit(x_train, y_train.ravel())
  y_pred=regressor.predict(x_test)
  y_pred=np.around(y_pred,0)
  # print(y_pred)
  qwk=metrics.cohen_kappa_score(y_test, y_pred, labels=None, weights='quadratic', sample_weight=None)
  print("Quadratic Weighted Kappa for support vector: "+" "+str(qwk))
  # except:
  #   print("Error in prompt "+str(a))
SV(2)
# Out:
# Quadratic Weighted Kappa for support vector:  0.7842279559686788

# %%
def xgb():
  # a=x
#   try:
  name="/content/drive/MyDrive/EG/translated_dataset/google_translator/nep_p8_fe"
  name=name+'.csv'
  df = pd.read_csv(name)
  df.overlap_score= (df.overlap_score-df.overlap_score.min())/(df.overlap_score.max()-df.overlap_score.min())
  df.unique_words_count= (df.unique_words_count-df.unique_words_count.min())/(df.unique_words_count.max()-df.unique_words_count.min())
  df.essay_length= (df.essay_length-df.essay_length.min())/(df.essay_length.max()-df.essay_length.min())
  df.average_sentence_length= (df.average_sentence_length-df.average_sentence_length.min())/(df.average_sentence_length.max()-df.average_sentence_length.min())
  df.average_word_length= (df.average_word_length-df.average_word_length.min())/(df.average_word_length.max()-df.average_word_length.min())
  df.readability= (df.readability-df.readability.min())/(df.readability.max()-df.readability.min())
  df = df.dropna(subset=['score'])
  x=df[['unique_words_count','overlap_score','essay_length','average_sentence_length','average_word_length','readability']]
  y=df['score']
  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=42)

  x_test, x_valid, y_test, y_valid = train_test_split(x_test, y_test, test_size = 0.5, random_state=42)

  model = xgboost.XGBRegressor()
  model.fit(x_train,y_train)
  y_pred = model.predict(x_test)
  y_pred=np.around(y_pred,0)
    # print(y_pred)
  qwk=metrics.cohen_kappa_score(y_test, y_pred, labels=None, weights='quadratic', sample_weight=None)
  print("Quadratic Weighted Kappa for xgb: "+str(qwk))
  # except:
  #   print("Error in prompt "+str(a))
xgb()
# Out:
# Quadratic Weighted Kappa for xgb: 0.7634441834590184

# %%
def naive_bayes():
    name = "/content/drive/MyDrive/EG/translated_dataset/google_translator/nep_p8_fe"
    name = name + '.csv'
    df = pd.read_csv(name)
    df.overlap_score = (df.overlap_score - df.overlap_score.min()) / (df.overlap_score.max() - df.overlap_score.min())
    df.unique_words_count = (df.unique_words_count - df.unique_words_count.min()) / (df.unique_words_count.max() - df.unique_words_count.min())
    df.essay_length = (df.essay_length - df.essay_length.min()) / (df.essay_length.max() - df.essay_length.min())
    df.average_sentence_length = (df.average_sentence_length - df.average_sentence_length.min()) / (
                df.average_sentence_length.max() - df.average_sentence_length.min())
    df.average_word_length = (df.average_word_length - df.average_word_length.min()) / (
                df.average_word_length.max() - df.average_word_length.min())
    df.readability = (df.readability - df.readability.min()) / (df.readability.max() - df.readability.min())
    df = df.dropna(subset=['score'])
    x = df[['unique_words_count', 'overlap_score', 'essay_length', 'average_sentence_length', 'average_word_length', 'readability']]
    y = df['score']
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
    x_test, x_valid, y_test, y_valid = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

    model = GaussianNB()
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    y_pred = np.around(y_pred, 0)
    qwk = metrics.cohen_kappa_score(y_test, y_pred, labels=None, weights='quadratic', sample_weight=None)
    print("Quadratic Weighted Kappa for Naive Bayes: " + str(qwk))

naive_bayes()
# Out:
# Quadratic Weighted Kappa for Naive Bayes: 0.7334022352240479

# %%
def decision_tree():
    name = "/content/drive/MyDrive/EG/translated_dataset/google_translator/nep_p8_fe"
    name = name + '.csv'
    df = pd.read_csv(name)
    df.overlap_score = (df.overlap_score - df.overlap_score.min()) / (df.overlap_score.max() - df.overlap_score.min())
    df.unique_words_count = (df.unique_words_count - df.unique_words_count.min()) / (df.unique_words_count.max() - df.unique_words_count.min())
    df.essay_length = (df.essay_length - df.essay_length.min()) / (df.essay_length.max() - df.essay_length.min())
    df.average_sentence_length = (df.average_sentence_length - df.average_sentence_length.min()) / (
                df.average_sentence_length.max() - df.average_sentence_length.min())
    df.average_word_length = (df.average_word_length - df.average_word_length.min()) / (
                df.average_word_length.max() - df.average_word_length.min())
    df.readability = (df.readability - df.readability.min()) / (df.readability.max() - df.readability.min())
    df = df.dropna(subset=['score'])
    x = df[['unique_words_count', 'overlap_score', 'essay_length', 'average_sentence_length', 'average_word_length', 'readability']]
    y = df['score']
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
    x_test, x_valid, y_test, y_valid = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

    model = DecisionTreeRegressor(random_state=42)
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    y_pred = np.around(y_pred, 0)
    qwk = metrics.cohen_kappa_score(y_test, y_pred, labels=None, weights='quadratic', sample_weight=None)
    print("Quadratic Weighted Kappa for Decision Tree: " + str(qwk))

# Call the function
decision_tree()
# Out:
# Quadratic Weighted Kappa for Decision Tree: 0.6741017491031431

# %%
from sklearn.ensemble import AdaBoostRegressor

def ada_boost():
    name = "/content/drive/MyDrive/EG/translated_dataset/google_translator/nep_p8_fe"
    name = name + '.csv'
    df = pd.read_csv(name)
    df.overlap_score = (df.overlap_score - df.overlap_score.min()) / (df.overlap_score.max() - df.overlap_score.min())
    df.unique_words_count = (df.unique_words_count - df.unique_words_count.min()) / (df.unique_words_count.max() - df.unique_words_count.min())
    df.essay_length = (df.essay_length - df.essay_length.min()) / (df.essay_length.max() - df.essay_length.min())
    df.average_sentence_length = (df.average_sentence_length - df.average_sentence_length.min()) / (
                df.average_sentence_length.max() - df.average_sentence_length.min())
    df.average_word_length = (df.average_word_length - df.average_word_length.min()) / (
                df.average_word_length.max() - df.average_word_length.min())
    df.readability = (df.readability - df.readability.min()) / (df.readability.max() - df.readability.min())
    df = df.dropna(subset=['score'])
    x = df[['unique_words_count', 'overlap_score', 'essay_length', 'average_sentence_length', 'average_word_length', 'readability']]
    y = df['score']
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
    x_test, x_valid, y_test, y_valid = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

    model = AdaBoostRegressor(random_state=42)
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    y_pred = np.around(y_pred, 0)
    qwk = metrics.cohen_kappa_score(y_test, y_pred, labels=None, weights='quadratic', sample_weight=None)
    print("Quadratic Weighted Kappa for AdaBoost: " + str(qwk))

# Call the function
ada_boost()
# Out:
# Quadratic Weighted Kappa for AdaBoost: 0.7594928596605535

# %%
print(naive_bayes(), SV(2), LR2(), RF(), decision_tree(), xgb(), ada_boost())
# Out:
# Quadratic Weighted Kappa for Naive Bayes: 0.7334022352240479
# Quadratic Weighted Kappa for support vector:  0.7842279559686788
# Quadratic Weighted Kappa for Linear Regression: 0.7813766441060934
# Quadratic Weighted Kappa for Random Forest: 0.7368328600286911
# Quadratic Weighted Kappa for Decision Tree: 0.6741017491031431
# Quadratic Weighted Kappa for xgb: 0.7634441834590184
# Quadratic Weighted Kappa for AdaBoost: 0.7594928596605535
# None None None None None None None

# %%
# from sklearn.ensemble import AdaBoostRegressor
# from sklearn import metrics
# from scipy import stats

# def ada_boost():
#     name = "/content/drive/MyDrive/Essay_Grading/translated_dataset/google_translator/nep_p8_fe"
#     name = name + '.csv'
#     df = pd.read_csv(name)
#     df.overlap_score = (df.overlap_score - df.overlap_score.min()) / (df.overlap_score.max() - df.overlap_score.min())
#     df.unique_words_count = (df.unique_words_count - df.unique_words_count.min()) / (df.unique_words_count.max() - df.unique_words_count.min())
#     df.essay_length = (df.essay_length - df.essay_length.min()) / (df.essay_length.max() - df.essay_length.min())
#     df.average_sentence_length = (df.average_sentence_length - df.average_sentence_length.min()) / (
#                 df.average_sentence_length.max() - df.average_sentence_length.min())
#     df.average_word_length = (df.average_word_length - df.average_word_length.min()) / (
#                 df.average_word_length.max() - df.average_word_length.min())
#     df.readability = (df.readability - df.readability.min()) / (df.readability.max() - df.readability.min())
#     df = df.dropna(subset=['score'])
#     x = df[['unique_words_count', 'overlap_score', 'essay_length', 'average_sentence_length', 'average_word_length', 'readability']]
#     y = df['score']
#     x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=42)
#     x_test, x_valid, y_test, y_valid = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

#     model = AdaBoostRegressor()
#     model.fit(x_train, y_train)
#     y_pred = model.predict(x_test)
#     y_pred = np.around(y_pred, 0)

#     mse = metrics.mean_squared_error(y_test, y_pred)
#     mae = metrics.mean_absolute_error(y_test, y_pred)
#     r2 = metrics.r2_score(y_test, y_pred)
#     pearson_corr, _ = stats.pearsonr(y_test, y_pred)
#     spearman_corr, _ = stats.spearmanr(y_test, y_pred)
#     qwk = metrics.cohen_kappa_score(y_test, y_pred, labels=None, weights='quadratic', sample_weight=None)

#     print("Quadratic Weighted Kappa for AdaBoost: " + str(qwk))
#     print(f'MSE: {mse}')
#     print(f'MAE: {mae}')
#     print(f'R2: {r2}')
#     print(f'Pearson Correlation: {pearson_corr}')
#     print(f'Spearman Correlation: {spearman_corr}')

# # Call the function
# ada_boost()
